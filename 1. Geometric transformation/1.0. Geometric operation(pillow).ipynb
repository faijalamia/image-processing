# %%
#!pip install pillow

# %%
from PIL import Image,ImageOps
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img  = Image.open('/content/drive/MyDrive/Colab Notebooks/1. Geometric transformation/robot.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=486x498>

# %%
cropped = img.crop((100, 100, 300, 300))
cropped
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200>

# %%
resized = img.resize((256,256))
resized
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256>

# %%
np_img = np.array(img)
rescaled = np_img/255.0
rescaled
# Out:
# array([[[0.09411765, 0.1254902 , 0.15686275, 1.        ],
#         [0.09411765, 0.12156863, 0.16470588, 1.        ],
#         [0.09411765, 0.12156863, 0.17254902, 1.        ],
#         ...,
#         [0.39215686, 0.63529412, 0.74901961, 1.        ],
#         [0.38823529, 0.62745098, 0.74509804, 1.        ],
#         [0.38431373, 0.62352941, 0.74117647, 1.        ]],
#
#        [[0.        , 0.00392157, 0.04313725, 1.        ],
#         [0.        , 0.        , 0.05098039, 1.        ],
#         [0.        , 0.        , 0.05098039, 1.        ],
#         ...,
#         [0.18039216, 0.58823529, 0.78039216, 1.        ],
#         [0.18039216, 0.58823529, 0.78039216, 1.        ],
#         [0.17254902, 0.58039216, 0.77254902, 1.        ]],
#
#        [[0.02352941, 0.06666667, 0.11372549, 1.        ],
#         [0.02352941, 0.06666667, 0.12156863, 1.        ],
#         [0.02745098, 0.0627451 , 0.12156863, 1.        ],
#         ...,
# ...

# %%
img1 = ImageOps.mirror(img)
img1
# Out:
# <PIL.Image.Image image mode=RGBA size=486x498>

# %%
img2 = ImageOps.flip(img)
img2
# Out:
# <PIL.Image.Image image mode=RGBA size=486x498>

# %%
img3 = img.rotate(45)
img3
# Out:
# <PIL.Image.Image image mode=RGBA size=486x498>
